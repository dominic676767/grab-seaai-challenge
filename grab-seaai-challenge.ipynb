# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('./training.csv')
data.head()
data[(data.geohash6 == 'qp03wc') & (data.day == 1)]
# Out:
#         geohash6  day timestamp    demand
# 9418      qp03wc    1      3:15  0.241169
# 50259     qp03wc    1     11:45  0.455879
# 69076     qp03wc    1      11:0  0.474736
# 148436    qp03wc    1      7:30  0.349503
# 173920    qp03wc    1      7:45  0.455028
# 238876    qp03wc    1      14:0  0.475497
# 272861    qp03wc    1      13:0  0.380835
# 320129    qp03wc    1     12:45  0.434543
# 331899    qp03wc    1     12:30  0.495320
# 414713    qp03wc    1     11:30  0.398397
# 422079    qp03wc    1     22:30  0.099682
# 432515    qp03wc    1      8:15  0.418536
# 438687    qp03wc    1     17:45  0.010746
# 462758    qp03wc    1     15:45  0.105886
# 496951    qp03wc    1       1:0  0.062867
# 500422    qp03wc    1     10:15  0.428681
# 511095    qp03wc    1      10:0  0.439062
# 523172    qp03wc    1     13:45  0.464831
# 583368    qp03wc    1      1:15  0.056765
# 729515    qp03wc    1     12:15  0.515115
# 739373    qp03wc    1     23:45  0.290571
# ...
