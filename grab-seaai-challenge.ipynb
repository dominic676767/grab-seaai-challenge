# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('./training.csv')
data.columns
# data[(data.geohash6 == 'qp03wc') & (data.day == 1)]
# Out:
# Index(['geohash6', 'day', 'timestamp', 'demand'], dtype='object')

# %%
data.head()
# Out:
#   geohash6  day timestamp    demand
# 0   qp03wc   18      20:0  0.020072
# 1   qp03pn   10     14:30  0.024721
# 2   qp09sw    9      6:15  0.102821
# 3   qp0991   32       5:0  0.088755
# 4   qp090q   15       4:0  0.074468

# %%
sns.distplot(data['demand']);

# %%
print("Skewness: %f" % data['demand'].skew())
print("Kurtosis: %f" % data['demand'].kurt())
# Out:
# Skewness: 3.371201
# Kurtosis: 13.478949

# %%
data[(data['geohash6'] == 'qp03wc') & (data['timestamp'] == '12:0') ].sort_values(['demand'])
# Out:
#         geohash6  day timestamp    demand
# 1373338   qp03wc   43      12:0  0.276193
# 3847705   qp03wc   41      12:0  0.307287
# 1610334   qp03wc    7      12:0  0.405377
# 623921    qp03wc   14      12:0  0.411680
# 3687063   qp03wc   46      12:0  0.430436
# 159351    qp03wc   47      12:0  0.432681
# 711656    qp03wc   40      12:0  0.433668
# 3433746   qp03wc   27      12:0  0.437854
# 2176695   qp03wc    1      12:0  0.443888
# 3581869   qp03wc   22      12:0  0.447701
# 295023    qp03wc   26      12:0  0.454105
# 2800433   qp03wc   55      12:0  0.454481
# 2767272   qp03wc   33      12:0  0.463252
# 3335735   qp03wc   35      12:0  0.467037
# 152945    qp03wc    9      12:0  0.488335
# 2036713   qp03wc   57      12:0  0.503617
# 3574540   qp03wc   10      12:0  0.504823
# 290698    qp03wc   29      12:0  0.512851
# 722202    qp03wc   48      12:0  0.526702
# 453042    qp03wc   34      12:0  0.536452
# 415782    qp03wc   38      12:0  0.553672
# ...
